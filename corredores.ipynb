# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/etl-data-pipeline/blob/main/corredores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 43.2 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
database_url = "postgresql://corredores_user:AK2ZKvRJu5FFCwEEcmRGTxgj6tGjx3TP@dpg-d6uni794tr6s7390r1m0-a.oregon-postgres.render.com/corredores"

# %%
engine = create_engine("postgresql://corredores_user:AK2ZKvRJu5FFCwEEcmRGTxgj6tGjx3TP@dpg-d6uni794tr6s7390r1m0-a.oregon-postgres.render.com/corredores")

# %%
test = pd.read_sql("SELECT 1", engine)

# %%
print(test)
# Out:
#    ?column?
# 0         1

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline/refs/heads/main/corredores.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    id_corredor               nombre         zona    nivel  anios_experiencia
# 0            1    José López Flores  Paracentral      Mid                4.0
# 1            2    José Ortiz García     Centro     Junior                0.0
# 2            3   María Ramírez Cruz       Centro  SENIOR                 6.0
# 3            4  Fernanda Rojas Cruz          NaN  SENIOR                 8.0
# 4            5      Ana Gómez Rojas          NaN   Senior                4.0

# %%
df.shape
# Out:
# (80, 5)

# %%
df.columns
# Out:
# Index(['id_corredor', 'nombre', 'zona', 'nivel', 'anios_experiencia'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_corredor        80 non-null     int64
#  1   nombre             80 non-null     object
#  2   zona               63 non-null     object
#  3   nivel              68 non-null     object
#  4   anios_experiencia  76 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.3+ KB

# %%
df.isnull().sum()
# Out:
# id_corredor           0
# nombre                0
# zona                 17
# nivel                12
# anios_experiencia     4
# dtype: int64

# %%
clientes = df.copy()

# %%
clientes.columns = clientes.columns.str.strip().str.lower()

# %%
for col in clientes.select_dtypes(include='object').columns:

    clientes[col] = clientes[col].astype(str).str.strip()

# %%
clientes = clientes.replace(r'^\s*$', pd.NA, regex=True)

# %%
clientes = clientes.drop_duplicates()

# %%
def motivo(row):

    motivos = []

# %%
# !pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine
import pandas as pd

database_url = "postgresql://etl_user:H1p5ZGWEjVtVLYwGVZgLHieAbGWE48cy@dpg-d6qt0ecr85hc73f3paqg-a.oregon-postgres.render.com/etl_seguros"

engine = create_engine(database_url)

test = pd.read_sql("SELECT 1", engine)

print(test)
# Out:
# ...
#    ?column?
# 0         1

# %%
pd.read_sql(

"SELECT * FROM clientes_curated LIMIT 10",

engine

)
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
# 5           6  Ricardo López Vásquez  ricardo.lopez.vasquez6@seguro.sv
# 6           7     Diego Flores Rojas   diego.flores.rojas0@example.com
# 7           8      Karla Ortiz López       karla.ortiz.lopez1@mail.com
# 8           9    Juan Flores Morales  juan.flores.morales2@example.com
# 9          10    María Aguilar López  maria.aguilar.lopez3@example.com
#
#       genero fecha_nacimiento        ciudad segmento
# 0     Hombre       2011-11-24     SanMiguel      nan
# 1        nan              NaT      Sta. Ana      nan
# ...
